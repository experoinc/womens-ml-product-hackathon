# %%
# imports

# %%
cl <- ifelse(p > 0.5, "M", "R")
table(cl, test$Class)


The caret package offers it’s own, more informative function to calculate a confusion matrix:

confusionMatrix(cl, test$Class)

# %% [markdown]
# # Load and Clean Data

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Categorical Variable NaN Fill

# %% [markdown]
# # One Hot Encoding
